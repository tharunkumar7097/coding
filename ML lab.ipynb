# %%
import numpy as np
arr1=np.array([[1,2,3,4],[3,5,6,7]])
arr2=np.array([[1,2,3],[4,5,6]],ndmin=3)
print(arr1[1,2:])
print(arr1[1,1:2])
print(arr1.ndim)
print(arr2)
print(arr2[0,1,1])
# Out:
# [6 7]
# [5]
# 2
# [[[1 2 3]
#   [4 5 6]]]
# 5

# %%
from numpy import random
import numpy as np
a=random.randint(245)
arr1=random.randint(4,size=(1,6))
print(arr1)
print(a)
print(random.rand(3))
print(random.choice([2,4,5,6],size=[1,7]))
print(random.choice([1,2,3,4],p=(0.3,0.7,0.0,0.0),size=10))
arr2=np.array([1,3,4,5])
random.shuffle(arr2)
print(arr2)
print(random.permutation(arr1))
# Out:
# [[1 0 3 2 0 3]]
# 128
# [0.97306562 0.5333662  0.68193858]
# [[2 5 4 2 6 6 2]]
# [1 2 2 2 2 1 1 1 1 2]
# [3 4 1 5]
# [[1 0 3 2 0 3]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(2,2,1000),hist=False)
plt.show()
# Out:
# C:\Users\tharu\AppData\Local\Temp\ipykernel_82480\3834164150.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(2,2,1000),hist=False)

# %%
sns.distplot(random.binomial(18,0.6,1000),hist=True,kde=False)
# Out:
# C:\Users\tharu\AppData\Local\Temp\ipykernel_82480\1512258050.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(18,0.6,1000),hist=True,kde=False)
# <AxesSubplot: >

# %%
sns.distplot(random.normal(4,2,100),hist=False,label='normal')
sns.distplot(random.binomial(8,0.2,100),hist=False,label='binomial')
plt.show()
# Out:
# C:\Users\tharu\AppData\Local\Temp\ipykernel_82480\2150880629.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(4,2,100),hist=False,label='normal')
# C:\Users\tharu\AppData\Local\Temp\ipykernel_82480\2150880629.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
import pandas as pd
data={
    "name":[3,5],
    "class":[2,3]
}
d=pd.DataFrame(data,index=('a','b'))
print(d)
# Out:
#    name  class
# a     3      2
# b     5      3

# %%
df=pd.read_csv('C:/Users/tharu/Downloads/data_DT.csv')
df.plot()
df.corr()
# Out:
# C:\Users\tharu\AppData\Local\Temp\ipykernel_82480\3708207163.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  Age  Experience      Rank
# Age         1.000000    0.216344 -0.055215
# Experience  0.216344    1.000000  0.218768
# Rank       -0.055215    0.218768  1.000000

# %%
df.plot(kind='scatter',x='Age',y='Rank')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Rank'>

# %%
df['Experience'].plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
from sklearn import metrics
from numpy import random
import matplotlib.pyplot as plt
actual=random.binomial(1,0.9,1000)
predicted=random.binomial(1,0.9,1000)
confusion_matrix=metrics.confusion_matrix(actual,predicted)
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[False,True])
cm_display.plot()
plt.show()
accuracy=metrics.accuracy_score(actual,predicted)
precision=metrics.precision_score(actual,predicted)
sensitivity=metrics.recall_score(actual,predicted)
specificity=metrics.recall_score(actual,predicted,pos_label=0)
f1_score=metrics.f1_score(actual,predicted)
print("Accuracy :",accuracy,"preision:",precision,"sensitivity:",sensitivity,"specificity:",specificity,"f1_score:",f1_score)
print("Accuracy:",accuracy)
# Out:
# Accuracy : 0.816 preision: 0.8962053571428571 sensitivity: 0.8982102908277405 specificity: 0.12264150943396226 f1_score: 0.8972067039106145
# Accuracy: 0.816

# %%
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/tharu/Downloads/data_DT.csv")
print(df)
d={"UK":0,"USA":1,"N":2}
df['Nationality']=df['Nationality'].map(d)
d={'YES':1,'NO':0}
df['Go']=df['Go'].map(d)
features=['Age','Experience','Rank','Nationality']
x=df[features]
y=df['Go']
dtree=DecisionTreeClassifier()
dtree=dtree.fit(x,y)
tree.plot_tree(dtree,feature_names=features)
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES
# [Text(0.4, 0.9, 'Rank <= 6.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.2, 0.7, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6, 0.7, 'Nationality <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.4, 0.5, 'Age <= 35.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
# ...

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
x=np.array([5,15,25,35,45,55]).reshape(-1,1)
y=np.array([5,20,14,32,22,38])
model=LinearRegression().fit(x,y)
r_sq=model.score(x,y)
print('coefficient of determination',r_sq)
print('slope',model.coef_)
print('intercept',model.intercept_)
# Out:
# coefficient of determination 0.7158756137479542
# slope [0.54]
# intercept 5.633333333333329

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df

# %%
pip install pygal

# %%
pip install numpy
